# %%
# Cell 1: The Magic Setup
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import json
import sys
from pathlib import Path
from src.services.analytics.match_ratings_service import MatchRatingsService

# %%
# Define the project root (one folder up from /workshop)
project_root = Path("..").resolve()

# Add the project root to sys.path so Jupyter can find your 'src' module
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

# %%
# Import weights and means_stds from config/performance_weights.json and config/performance_means_stds.json
weights_path = project_root / 'config' / 'performance_weights.json'
means_stds_path = project_root / 'config' / 'performance_means_stds.json'
with open(weights_path, 'r') as f:
    weights = json.load(f)
with open(means_stds_path, 'r') as f:
    means_stds = json.load(f)

# %%
# The Standard Match Overview (4-minute halves)
test_overview = {
    "in_game_date": "2031-01-21T00:00:00",
    "half_length": 4,  # Triggers the 2.5x temporal scalar
    "competition": "UEFA Champions League",
    "home_team_name": "Test FC", "away_team_name": "Opponent FC",
    "home_score": 2, "away_score": 1,
    "home_stats": {"possession": 50, "xg": 2.1},
    "away_stats": {"possession": 50, "xg": 1.2}
}
team_name = "Test FC"

test_1_golden_sub = {
    "performance_type": "Outfield", "positions_played": ["ST"], "minutes_played": 15.0,
    "goals": 1, "assists": 0, "shots": 1, "shot_accuracy": 100,
    "passes": 2, "pass_accuracy": 100, "dribbles": 0, "dribble_success_rate": 0,
    "tackles": 0, "tackle_success_rate": 0, "offsides": 0, "fouls_committed": 0,
    "possession_won": 0, "possession_lost": 1, "distance_covered": 1.8, "distance_sprinted": 0.4
}

test_2_frantic_playmaker = {
    "performance_type": "Outfield", "positions_played": ["CAM"], "minutes_played": 25.0,
    "goals": 0, "assists": 1, "shots": 1, "shot_accuracy": 0,
    "passes": 12, "pass_accuracy": 90, "dribbles": 5, "dribble_success_rate": 80,
    "tackles": 1, "tackle_success_rate": 100, "offsides": 0, "fouls_committed": 0,
    "possession_won": 2, "possession_lost": 2, "distance_covered": 3.5, "distance_sprinted": 1.1
}

test_3_recovery_cb = {
    "performance_type": "Outfield", "positions_played": ["CB"], "minutes_played": 90.0,
    "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,
    "passes": 18, "pass_accuracy": 85, "dribbles": 1, "dribble_success_rate": 100,
    "tackles": 2, "tackle_success_rate": 50, "offsides": 0, "fouls_committed": 1,
    "possession_won": 2, "possession_lost": 6, 
    "distance_covered": 10.0, "distance_sprinted": 3.5  # Huge sprint distance
}

test_4_nightmare_cb = {
    "performance_type": "Outfield", "positions_played": ["CB"], "minutes_played": 90.0,
    "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,
    "passes": 14, "pass_accuracy": 65, "dribbles": 0, "dribble_success_rate": 0,
    "tackles": 1, "tackle_success_rate": 20, "offsides": 0, 
    "fouls_committed": 3, "possession_won": 1, "possession_lost": 8, 
    "distance_covered": 9.5, "distance_sprinted": 1.0
}

test_5_masterclass_st = {
    "performance_type": "Outfield", "positions_played": ["ST"], "minutes_played": 90.0,
    "goals": 2, "assists": 1, "shots": 5, "shot_accuracy": 60,
    "passes": 18, "pass_accuracy": 85, "dribbles": 7, "dribble_success_rate": 70,
    "tackles": 1, "tackle_success_rate": 100, "offsides": 1, "fouls_committed": 0,
    "possession_won": 2, "possession_lost": 3, "distance_covered": 11.2, "distance_sprinted": 2.8
}

tests = {
    "1. Golden Sub (15m, 1 Goal)": test_1_golden_sub,
    "2. Frantic Playmaker (25m, High Vol)": test_2_frantic_playmaker,
    "3. Recovery CB (90m, False Sprint)": test_3_recovery_cb,
    "4. Nightmare CB (90m, 8 Poss Lost)": test_4_nightmare_cb,
    "5. Masterclass ST (90m, 2G 1A)": test_5_masterclass_st
}

print("--- GAFFER'S CLIPBOARD ENGINE STRESS TEST ---")
for name, payload in tests.items():
    # Make sure to pass your imported weights and means_stds
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    
    # Run the engine
    rating = service.calculate_outfield_rating(
        payload, test_overview, half_length=4, team_name=team_name
    )
    print(f"{name.ljust(40)} => Rating: {rating}")
# Out:
# --- GAFFER'S CLIPBOARD ENGINE STRESS TEST ---
# 1. Golden Sub (15m, 1 Goal)              => Rating: 8.3
# 2. Frantic Playmaker (25m, High Vol)     => Rating: 8.8
# 3. Recovery CB (90m, False Sprint)       => Rating: 5.4
# 4. Nightmare CB (90m, 8 Poss Lost)       => Rating: 4.2
# 5. Masterclass ST (90m, 2G 1A)           => Rating: 9.9

# %%
# The Standard Match Overview (10-minute halves)
test_overview_10m = {
    "in_game_date": "2031-01-21T00:00:00",
    "half_length": 10,  # Temporal scalar is exactly 1.0
    "competition": "UEFA Champions League",
    "home_team_name": "Test FC", "away_team_name": "Opponent FC",
    "home_score": 2, "away_score": 1,
    "home_stats": {"possession": 50, "xg": 2.1},
    "away_stats": {"possession": 50, "xg": 1.2}
}
team_name = "Test FC"

test_1_golden_sub_10m = {
    "performance_type": "Outfield", "positions_played": ["ST"], "minutes_played": 15.0,
    "goals": 1, "assists": 0, "shots": 1, "shot_accuracy": 100,
    "passes": 5, "pass_accuracy": 100, "dribbles": 1, "dribble_success_rate": 100,
    "tackles": 0, "tackle_success_rate": 0, "offsides": 0, "fouls_committed": 0,
    "possession_won": 0, "possession_lost": 2, "distance_covered": 2.1, "distance_sprinted": 0.5
}

test_2_frantic_playmaker_10m = {
    "performance_type": "Outfield", "positions_played": ["CAM"], "minutes_played": 25.0,
    "goals": 0, "assists": 1, "shots": 2, "shot_accuracy": 50,
    "passes": 28, "pass_accuracy": 90, "dribbles": 12, "dribble_success_rate": 80,
    "tackles": 2, "tackle_success_rate": 100, "offsides": 0, "fouls_committed": 0,
    "possession_won": 4, "possession_lost": 5, "distance_covered": 4.2, "distance_sprinted": 1.3
}

test_3_recovery_cb_10m = {
    "performance_type": "Outfield", "positions_played": ["CB"], "minutes_played": 90.0,
    "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,
    "passes": 42, "pass_accuracy": 85, "dribbles": 2, "dribble_success_rate": 100,
    "tackles": 4, "tackle_success_rate": 50, "offsides": 0, "fouls_committed": 1,
    "possession_won": 4, "possession_lost": 15, # Awful ratio
    "distance_covered": 11.5, "distance_sprinted": 6.5  # Absurdly high sprint distance
}

test_4_nightmare_cb_10m = {
    "performance_type": "Outfield", "positions_played": ["CB"], "minutes_played": 90.0,
    "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,
    "passes": 35, "pass_accuracy": 65, "dribbles": 0, "dribble_success_rate": 0,
    "tackles": 2, "tackle_success_rate": 20, "offsides": 0, 
    "fouls_committed": 4, "possession_won": 2, "possession_lost": 20, # Catastrophic
    "distance_covered": 10.5, "distance_sprinted": 2.0
}

test_5_masterclass_st_10m = {
    "performance_type": "Outfield", "positions_played": ["ST"], "minutes_played": 90.0,
    "goals": 2, "assists": 1, "shots": 6, "shot_accuracy": 66,
    "passes": 40, "pass_accuracy": 85, "dribbles": 18, "dribble_success_rate": 75,
    "tackles": 2, "tackle_success_rate": 100, "offsides": 1, "fouls_committed": 0,
    "possession_won": 4, "possession_lost": 7, "distance_covered": 11.8, "distance_sprinted": 3.2
}

tests_10m = {
    "1. Golden Sub (10m Half)": test_1_golden_sub_10m,
    "2. Frantic Playmaker (10m Half)": test_2_frantic_playmaker_10m,
    "3. Recovery CB (10m Half)": test_3_recovery_cb_10m,
    "4. Nightmare CB (10m Half)": test_4_nightmare_cb_10m,
    "5. Masterclass ST (10m Half)": test_5_masterclass_st_10m
}

print("--- 10-MINUTE HALF BASELINE TEST ---")
for name, payload in tests_10m.items():
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    rating = service.calculate_outfield_rating(
        payload, test_overview_10m, half_length=10, team_name=team_name
    )
    print(f"{name.ljust(35)} => Rating: {rating}")
# Out:
# --- 10-MINUTE HALF BASELINE TEST ---
# 1. Golden Sub (10m Half)            => Rating: 8.0
# 2. Frantic Playmaker (10m Half)     => Rating: 8.5
# 3. Recovery CB (10m Half)           => Rating: 5.1
# 4. Nightmare CB (10m Half)          => Rating: 4.1
# 5. Masterclass ST (10m Half)        => Rating: 9.7

# %%
# The Control Baseline Overview
test_overview_sigmoid = {
    "in_game_date": "2031-01-21T00:00:00",
    "half_length": 10,  # 1.0 scalar keeps the raw volume exact
    "competition": "UEFA Champions League",
    "home_team_name": "Test FC", "away_team_name": "Opponent FC",
    "home_score": 0, "away_score": 0,
    "home_stats": {"possession": 50, "xg": 1.0},
    "away_stats": {"possession": 50, "xg": 1.0}
}
team_name = "Test FC"

# 6A: The Fluke (X = 1)
test_6a_fluke = {
    "performance_type": "Outfield", "positions_played": ["CM"], "minutes_played": 15.0,
    "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,
    "passes": 1, "pass_accuracy": 100, "dribbles": 0, "dribble_success_rate": 0, # <-- 1 Pass
    "tackles": 0, "tackle_success_rate": 0, "offsides": 0, "fouls_committed": 0,
    "possession_won": 0, "possession_lost": 0, "distance_covered": 1.8, "distance_sprinted": 0.2
}

# 6B: The Inflection (X = 3)
test_6b_inflection = test_6a_fluke.copy()
test_6b_inflection["passes"] = 3

# 6C: The Proof (X = 6)
test_6c_proof = test_6a_fluke.copy()
test_6c_proof["passes"] = 6

tests_sigmoid = {
    "6A. The Fluke (1 Pass)": test_6a_fluke,
    "6B. The Inflection (3 Passes)": test_6b_inflection,
    "6C. The Proof (6 Passes)": test_6c_proof
}

print("--- SIGMOID GRADIENT STRESS TEST ---")
for name, payload in tests_sigmoid.items():
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    rating = service.calculate_outfield_rating(
        payload, test_overview_sigmoid, half_length=10, team_name=team_name
    )
    print(f"{name.ljust(35)} => Rating: {rating}")
# Out:
# --- SIGMOID GRADIENT STRESS TEST ---
# 6A. The Fluke (1 Pass)              => Rating: 5.8
# 6B. The Inflection (3 Passes)       => Rating: 5.8
# 6C. The Proof (6 Passes)            => Rating: 5.9

# %%
# The Standard Match Overview (10-minute halves)
test_overview_finishing = {
    "in_game_date": "2031-01-21T00:00:00",
    "half_length": 10,  
    "competition": "UEFA Champions League",
    "home_team_name": "Test FC", "away_team_name": "Opponent FC",
    "home_score": 2, "away_score": 0,
    "home_stats": {"possession": 50, "xg": 2.0},
    "away_stats": {"possession": 50, "xg": 1.0}
}
team_name = "Test FC"

# 7A: The Clinical Assassin (2 Shots, 2 Goals)
test_7a_clinical = {
    "performance_type": "Outfield", "positions_played": ["ST"], "minutes_played": 90.0,
    "goals": 2, "assists": 0, "shots": 2, "shot_accuracy": 100,
    "passes": 15, "pass_accuracy": 85, "dribbles": 3, "dribble_success_rate": 66,
    "tackles": 1, "tackle_success_rate": 100, "offsides": 0, "fouls_committed": 0,
    "possession_won": 1, "possession_lost": 3, "distance_covered": 10.5, "distance_sprinted": 2.2
}

# 7B: The Wasteful Shooter (8 Shots, 2 Goals)
test_7b_wasteful = test_7a_clinical.copy()
test_7b_wasteful["shots"] = 8
test_7b_wasteful["shot_accuracy"] = 50 # 4 on target, 4 off target

tests_finishing = {
    "7A. Clinical Assassin (2 Shots, 2G)": test_7a_clinical,
    "7B. Wasteful Shooter (8 Shots, 2G)": test_7b_wasteful,
}

print("--- ORTHOGONALIZED PCA STRESS TEST ---")
for name, payload in tests_finishing.items():
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    rating = service.calculate_outfield_rating(
        payload, test_overview_finishing, half_length=10, team_name=team_name
    )
    print(f"{name.ljust(35)} => Rating: {rating}")
# Out:
# --- ORTHOGONALIZED PCA STRESS TEST ---
# 7A. Clinical Assassin (2 Shots, 2G) => Rating: 9.2
# 7B. Wasteful Shooter (8 Shots, 2G)  => Rating: 8.7

# %%
# Match 95: Elche CF 2-2 Valencia CF (La Liga, 2031-02-09)
# Draw with the widest rating spread in recent data (4.3 - 9.5)
match_95_overview = {
    "in_game_date": "2031-02-09T00:00:00",
    "half_length": 10,
    "competition": "La Liga",
    "home_team_name": "Elche CF",
    "away_team_name": "Valencia CF",
    "home_score": 2,
    "away_score": 2,
    "home_stats": {"possession": 51, "xg": 2.3},
    "away_stats": {"possession": 49, "xg": 3.6},
}
team_name = "Valencia CF"

match_95_outfield = [
    {"player_id": 33, "match_rating": 4.3,  "performance_type": "Outfield", "positions_played": ["LW"],       "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,   "passes": 0,  "pass_accuracy": 0,   "dribbles": 0,  "dribble_success_rate": 0,   "tackles": 0, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 0, "minutes_played": 14, "distance_covered": 1.5,  "distance_sprinted": 0.4},
    {"player_id": 48, "match_rating": 9.5,  "performance_type": "Outfield", "positions_played": ["ST"],       "goals": 2, "assists": 0, "shots": 3,  "shot_accuracy": 100,  "passes": 11, "pass_accuracy": 91,  "dribbles": 9,  "dribble_success_rate": 100, "tackles": 3, "tackle_success_rate": 67,  "offsides": 0, "fouls_committed": 0, "possession_won": 2, "possession_lost": 2, "minutes_played": 91, "distance_covered": 10.2, "distance_sprinted": 2.1},
    {"player_id": 66, "match_rating": 5.5,  "performance_type": "Outfield", "positions_played": ["RW"],       "goals": 0, "assists": 0, "shots": 3,  "shot_accuracy": 33,   "passes": 22, "pass_accuracy": 95,  "dribbles": 22, "dribble_success_rate": 91,  "tackles": 1, "tackle_success_rate": 100, "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 6, "minutes_played": 91, "distance_covered": 9.7,  "distance_sprinted": 2.0},
    {"player_id": 56, "match_rating": 5.5,  "performance_type": "Outfield", "positions_played": ["LW", "CM"], "goals": 0, "assists": 0, "shots": 1,  "shot_accuracy": 60,   "passes": 16, "pass_accuracy": 75,  "dribbles": 16, "dribble_success_rate": 94,  "tackles": 4, "tackle_success_rate": 25,  "offsides": 1, "fouls_committed": 0, "possession_won": 2, "possession_lost": 4, "minutes_played": 91, "distance_covered": 10.8, "distance_sprinted": 3.6},
    {"player_id": 31, "match_rating": 5.7,  "performance_type": "Outfield", "positions_played": ["CM"],       "goals": 0, "assists": 0, "shots": 1,  "shot_accuracy": 0,    "passes": 35, "pass_accuracy": 89,  "dribbles": 30, "dribble_success_rate": 97,  "tackles": 3, "tackle_success_rate": 33,  "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 5, "minutes_played": 77, "distance_covered": 8.8,  "distance_sprinted": 1.9},
    {"player_id": 24, "match_rating": 6.3,  "performance_type": "Outfield", "positions_played": ["CM"],       "goals": 0, "assists": 0, "shots": 1,  "shot_accuracy": 100,  "passes": 35, "pass_accuracy": 91,  "dribbles": 35, "dribble_success_rate": 89,  "tackles": 9, "tackle_success_rate": 22,  "offsides": 0, "fouls_committed": 0, "possession_won": 2, "possession_lost": 6, "minutes_played": 89, "distance_covered": 11.9, "distance_sprinted": 5.1},
    {"player_id": 11, "match_rating": 5.5,  "performance_type": "Outfield", "positions_played": ["CDM"],      "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,    "passes": 1,  "pass_accuracy": 100, "dribbles": 1,  "dribble_success_rate": 100, "tackles": 1, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 0, "minutes_played": 14, "distance_covered": 1.5,  "distance_sprinted": 0.4},
    {"player_id": 63, "match_rating": 7.4,  "performance_type": "Outfield", "positions_played": ["CDM"],      "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,    "passes": 40, "pass_accuracy": 98,  "dribbles": 35, "dribble_success_rate": 100, "tackles": 3, "tackle_success_rate": 67,  "offsides": 0, "fouls_committed": 0, "possession_won": 4, "possession_lost": 1, "minutes_played": 77, "distance_covered": 8.9,  "distance_sprinted": 2.3},
    {"player_id": 64, "match_rating": 5.8,  "performance_type": "Outfield", "positions_played": ["LB"],       "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,    "passes": 16, "pass_accuracy": 100, "dribbles": 13, "dribble_success_rate": 92,  "tackles": 9, "tackle_success_rate": 11,  "offsides": 0, "fouls_committed": 0, "possession_won": 3, "possession_lost": 0, "minutes_played": 91, "distance_covered": 9.4,  "distance_sprinted": 2.3},
    {"player_id": 62, "match_rating": 5.9,  "performance_type": "Outfield", "positions_played": ["CB"],       "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,    "passes": 18, "pass_accuracy": 94,  "dribbles": 13, "dribble_success_rate": 100, "tackles": 5, "tackle_success_rate": 80,  "offsides": 0, "fouls_committed": 0, "possession_won": 3, "possession_lost": 1, "minutes_played": 91, "distance_covered": 9.5,  "distance_sprinted": 2.4},
    {"player_id": 53, "match_rating": 4.4,  "performance_type": "Outfield", "positions_played": ["CB"],       "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,    "passes": 0,  "pass_accuracy": 0,   "dribbles": 0,  "dribble_success_rate": 0,   "tackles": 2, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 1, "possession_won": 0, "possession_lost": 0, "minutes_played": 14, "distance_covered": 1.5,  "distance_sprinted": 0.5},
    {"player_id": 14, "match_rating": 4.7,  "performance_type": "Outfield", "positions_played": ["CB"],       "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,    "passes": 8,  "pass_accuracy": 88,  "dribbles": 7,  "dribble_success_rate": 100, "tackles": 2, "tackle_success_rate": 50,  "offsides": 0, "fouls_committed": 0, "possession_won": 3, "possession_lost": 1, "minutes_played": 77, "distance_covered": 7.5,  "distance_sprinted": 1.6},
    {"player_id": 52, "match_rating": 6.3,  "performance_type": "Outfield", "positions_played": ["RB"],       "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,    "passes": 17, "pass_accuracy": 100, "dribbles": 16, "dribble_success_rate": 100, "tackles": 6, "tackle_success_rate": 17,  "offsides": 0, "fouls_committed": 0, "possession_won": 3, "possession_lost": 0, "minutes_played": 91, "distance_covered": 12.8, "distance_sprinted": 6.1},
]

print("--- REAL MATCH: Elche CF 2-2 Valencia CF (La Liga, 2031-02-09) ---")
for p in match_95_outfield:
    pos = "/".join(p["positions_played"])
    label = f"P{p['player_id']} {pos} {p['minutes_played']}m ({p['goals']}G {p['assists']}A)"
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    rating = service.calculate_outfield_rating(p, match_95_overview, half_length=10, team_name=team_name)
    print(f"{label.ljust(38)} => Rating: {rating}  [Prev. algo: {p['match_rating']}]")
# Out:
# --- REAL MATCH: Elche CF 2-2 Valencia CF (La Liga, 2031-02-09) ---
# P33 LW 14m (0G 0A)                     => Rating: 5.7  [Prev. algo: 4.3]
# P48 ST 91m (2G 0A)                     => Rating: 9.3  [Prev. algo: 9.5]
# P66 RW 91m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.5]
# P56 LW/CM 91m (0G 0A)                  => Rating: 5.8  [Prev. algo: 5.5]
# P31 CM 77m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.7]
# P24 CM 89m (0G 0A)                     => Rating: 6.1  [Prev. algo: 6.3]
# P11 CDM 14m (0G 0A)                    => Rating: 5.8  [Prev. algo: 5.5]
# P63 CDM 77m (0G 0A)                    => Rating: 7.5  [Prev. algo: 7.4]
# P64 LB 91m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.8]
# P62 CB 91m (0G 0A)                     => Rating: 5.8  [Prev. algo: 5.9]
# P53 CB 14m (0G 0A)                     => Rating: 5.7  [Prev. algo: 4.4]
# P14 CB 77m (0G 0A)                     => Rating: 5.4  [Prev. algo: 4.7]
# ...

# %%
# Match 96: Valencia CF 3-2 Atletico De Madrid (La Liga, 2031-02-15)
# Close home win vs top opposition, dominant possession (66%), strong GK performance
match_96_overview = {
    "in_game_date": "2031-02-15T00:00:00",
    "half_length": 10,
    "competition": "La Liga",
    "home_team_name": "Valencia CF",
    "away_team_name": "Atletico De Madrid",
    "home_score": 3,
    "away_score": 2,
    "home_stats": {"possession": 66, "xg": 5.5},
    "away_stats": {"possession": 34, "xg": 2.4},
}
team_name = "Valencia CF"

match_96_outfield = [
    {"player_id": 40, "match_rating": 7.2, "performance_type": "Outfield", "positions_played": ["LW"],  "goals": 0, "assists": 1, "shots": 0, "shot_accuracy": 0,   "passes": 14, "pass_accuracy": 86,  "dribbles": 11, "dribble_success_rate": 100, "tackles": 4, "tackle_success_rate": 50,  "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 2, "minutes_played": 92, "distance_covered": 11.7, "distance_sprinted": 4.3},
    {"player_id": 65, "match_rating": 5.2, "performance_type": "Outfield", "positions_played": ["ST"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 2,  "pass_accuracy": 100, "dribbles": 1,  "dribble_success_rate": 100, "tackles": 0, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 0, "minutes_played": 13, "distance_covered": 1.6,  "distance_sprinted": 0.3},
    {"player_id": 48, "match_rating": 9.3, "performance_type": "Outfield", "positions_played": ["ST"],  "goals": 1, "assists": 1, "shots": 3, "shot_accuracy": 67,  "passes": 15, "pass_accuracy": 100, "dribbles": 10, "dribble_success_rate": 100, "tackles": 1, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 2, "possession_lost": 2, "minutes_played": 79, "distance_covered": 8.8,  "distance_sprinted": 2.1},
    {"player_id": 66, "match_rating": 9.1, "performance_type": "Outfield", "positions_played": ["RW"],  "goals": 2, "assists": 0, "shots": 6, "shot_accuracy": 83,  "passes": 27, "pass_accuracy": 100, "dribbles": 35, "dribble_success_rate": 86,  "tackles": 1, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 6, "minutes_played": 92, "distance_covered": 10.5, "distance_sprinted": 2.6},
    {"player_id": 32, "match_rating": 5.8, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 0, "shots": 1, "shot_accuracy": 0,   "passes": 18, "pass_accuracy": 89,  "dribbles": 15, "dribble_success_rate": 100, "tackles": 0, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 3, "minutes_played": 42, "distance_covered": 5.7,  "distance_sprinted": 1.9},
    {"player_id": 56, "match_rating": 5.9, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 0, "shots": 1, "shot_accuracy": 100, "passes": 21, "pass_accuracy": 76,  "dribbles": 18, "dribble_success_rate": 94,  "tackles": 3, "tackle_success_rate": 67,  "offsides": 1, "fouls_committed": 0, "possession_won": 1, "possession_lost": 7, "minutes_played": 50, "distance_covered": 6.9,  "distance_sprinted": 3.2},
    {"player_id": 31, "match_rating": 6.2, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 25, "pass_accuracy": 96,  "dribbles": 19, "dribble_success_rate": 95,  "tackles": 1, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 2, "minutes_played": 42, "distance_covered": 4.9,  "distance_sprinted": 1.0},
    {"player_id": 24, "match_rating": 6.3, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 0, "shots": 1, "shot_accuracy": 0,   "passes": 28, "pass_accuracy": 82,  "dribbles": 21, "dribble_success_rate": 95,  "tackles": 3, "tackle_success_rate": 33,  "offsides": 0, "fouls_committed": 0, "possession_won": 2, "possession_lost": 6, "minutes_played": 50, "distance_covered": 6.9,  "distance_sprinted": 3.0},
    {"player_id": 63, "match_rating": 7.8, "performance_type": "Outfield", "positions_played": ["CDM"], "goals": 0, "assists": 0, "shots": 2, "shot_accuracy": 0,   "passes": 58, "pass_accuracy": 98,  "dribbles": 49, "dribble_success_rate": 92,  "tackles": 3, "tackle_success_rate": 33,  "offsides": 0, "fouls_committed": 1, "possession_won": 4, "possession_lost": 5, "minutes_played": 92, "distance_covered": 11.5, "distance_sprinted": 3.8},
    {"player_id": 64, "match_rating": 5.5, "performance_type": "Outfield", "positions_played": ["LB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 16, "pass_accuracy": 94,  "dribbles": 12, "dribble_success_rate": 100, "tackles": 6, "tackle_success_rate": 33,  "offsides": 0, "fouls_committed": 0, "possession_won": 4, "possession_lost": 1, "minutes_played": 92, "distance_covered": 10.0, "distance_sprinted": 2.9},
    {"player_id": 11, "match_rating": 6.0, "performance_type": "Outfield", "positions_played": ["CB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 9,  "pass_accuracy": 100, "dribbles": 5,  "dribble_success_rate": 100, "tackles": 1, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 0, "minutes_played": 31, "distance_covered": 3.8,  "distance_sprinted": 1.1},
    {"player_id": 62, "match_rating": 5.9, "performance_type": "Outfield", "positions_played": ["CB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 19, "pass_accuracy": 100, "dribbles": 19, "dribble_success_rate": 89,  "tackles": 3, "tackle_success_rate": 33,  "offsides": 0, "fouls_committed": 0, "possession_won": 3, "possession_lost": 1, "minutes_played": 61, "distance_covered": 6.9,  "distance_sprinted": 2.0},
    {"player_id": 53, "match_rating": 6.0, "performance_type": "Outfield", "positions_played": ["CB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 2,  "pass_accuracy": 100, "dribbles": 2,  "dribble_success_rate": 100, "tackles": 0, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 2, "possession_lost": 0, "minutes_played": 13, "distance_covered": 1.6,  "distance_sprinted": 0.5},
    {"player_id": 14, "match_rating": 5.5, "performance_type": "Outfield", "positions_played": ["CB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 16, "pass_accuracy": 88,  "dribbles": 11, "dribble_success_rate": 100, "tackles": 7, "tackle_success_rate": 14,  "offsides": 0, "fouls_committed": 0, "possession_won": 4, "possession_lost": 1, "minutes_played": 79, "distance_covered": 8.2,  "distance_sprinted": 2.1},
    {"player_id": 52, "match_rating": 6.5, "performance_type": "Outfield", "positions_played": ["RB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 30, "pass_accuracy": 77,  "dribbles": 25, "dribble_success_rate": 96,  "tackles": 5, "tackle_success_rate": 40,  "offsides": 0, "fouls_committed": 1, "possession_won": 5, "possession_lost": 4, "minutes_played": 92, "distance_covered": 13.8, "distance_sprinted": 7.7},
]

print("--- REAL MATCH: Valencia CF 3-2 Atletico De Madrid (La Liga, 2031-02-15) ---")
for p in match_96_outfield:
    pos = "/".join(p["positions_played"])
    label = f"P{p['player_id']} {pos} {p['minutes_played']}m ({p['goals']}G {p['assists']}A)"
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    rating = service.calculate_outfield_rating(p, match_96_overview, half_length=10, team_name=team_name)
    print(f"{label.ljust(38)} => Rating: {rating}  [Prev. algo: {p['match_rating']}]")
# Out:
# --- REAL MATCH: Valencia CF 3-2 Atletico De Madrid (La Liga, 2031-02-15) ---
# P40 LW 92m (0G 1A)                     => Rating: 7.6  [Prev. algo: 7.2]
# P65 ST 13m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.2]
# P48 ST 79m (1G 1A)                     => Rating: 9.3  [Prev. algo: 9.3]
# P66 RW 92m (2G 0A)                     => Rating: 8.5  [Prev. algo: 9.1]
# P32 CM 42m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.8]
# P56 CM 50m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.9]
# P31 CM 42m (0G 0A)                     => Rating: 5.8  [Prev. algo: 6.2]
# P24 CM 50m (0G 0A)                     => Rating: 6.0  [Prev. algo: 6.3]
# P63 CDM 92m (0G 0A)                    => Rating: 7.5  [Prev. algo: 7.8]
# P64 LB 92m (0G 0A)                     => Rating: 5.6  [Prev. algo: 5.5]
# P11 CB 31m (0G 0A)                     => Rating: 5.9  [Prev. algo: 6.0]
# P62 CB 61m (0G 0A)                     => Rating: 5.8  [Prev. algo: 5.9]
# ...

# %%
# Match 87: FC Barcelona 1-0 Valencia CF (Supercopa De España, 2031-01-12)
# A narrow loss — tests the algorithm under a losing result with mostly subdued ratings (4.6 - 7.1)
match_87_overview = {
    "in_game_date": "2031-01-12T00:00:00",
    "half_length": 10,
    "competition": "Supercopa De España",
    "home_team_name": "FC Barcelona",
    "away_team_name": "Valencia CF",
    "home_score": 1,
    "away_score": 0,
    "home_stats": {"possession": 46, "xg": 1.6},
    "away_stats": {"possession": 54, "xg": 3.2},
}
team_name = "Valencia CF"

match_87_outfield = [
    {"player_id": 40, "match_rating": 6.8, "performance_type": "Outfield", "positions_played": ["LW"],       "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 16, "pass_accuracy": 81,  "dribbles": 17, "dribble_success_rate": 82,  "tackles": 2, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0,  "possession_lost": 5, "minutes_played": 47, "distance_covered": 6.7,  "distance_sprinted": 2.9},
    {"player_id": 70, "match_rating": 5.3, "performance_type": "Outfield", "positions_played": ["LW"],       "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 6,  "pass_accuracy": 83,  "dribbles": 8,  "dribble_success_rate": 75,  "tackles": 0, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0,  "possession_lost": 3, "minutes_played": 45, "distance_covered": 6.1,  "distance_sprinted": 1.6},
    {"player_id": 48, "match_rating": 5.5, "performance_type": "Outfield", "positions_played": ["ST"],       "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 3,  "pass_accuracy": 100, "dribbles": 4,  "dribble_success_rate": 75,  "tackles": 0, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0,  "possession_lost": 1, "minutes_played": 21, "distance_covered": 2.5,  "distance_sprinted": 0.7},
    {"player_id": 65, "match_rating": 4.6, "performance_type": "Outfield", "positions_played": ["ST"],       "goals": 0, "assists": 0, "shots": 5, "shot_accuracy": 40, "passes": 4,  "pass_accuracy": 75,  "dribbles": 4,  "dribble_success_rate": 75,  "tackles": 2, "tackle_success_rate": 0,   "offsides": 1, "fouls_committed": 0, "possession_won": 0,  "possession_lost": 6, "minutes_played": 63, "distance_covered": 7.4,  "distance_sprinted": 1.6},
    {"player_id": 32, "match_rating": 7.0, "performance_type": "Outfield", "positions_played": ["CM", "ST"], "goals": 0, "assists": 0, "shots": 1, "shot_accuracy": 0,  "passes": 15, "pass_accuracy": 87,  "dribbles": 15, "dribble_success_rate": 93,  "tackles": 3, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0,  "possession_lost": 4, "minutes_played": 71, "distance_covered": 9.1,  "distance_sprinted": 3.1},
    {"player_id": 45, "match_rating": 5.0, "performance_type": "Outfield", "positions_played": ["RW"],       "goals": 0, "assists": 0, "shots": 3, "shot_accuracy": 67, "passes": 9,  "pass_accuracy": 89,  "dribbles": 10, "dribble_success_rate": 80,  "tackles": 2, "tackle_success_rate": 50,  "offsides": 2, "fouls_committed": 0, "possession_won": 2,  "possession_lost": 5, "minutes_played": 92, "distance_covered": 11.5, "distance_sprinted": 3.9},
    {"player_id": 31, "match_rating": 5.9, "performance_type": "Outfield", "positions_played": ["CM"],       "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 14, "pass_accuracy": 86,  "dribbles": 12, "dribble_success_rate": 92,  "tackles": 1, "tackle_success_rate": 100, "offsides": 0, "fouls_committed": 0, "possession_won": 2,  "possession_lost": 3, "minutes_played": 29, "distance_covered": 3.7,  "distance_sprinted": 1.0},
    {"player_id": 41, "match_rating": 5.9, "performance_type": "Outfield", "positions_played": ["CM"],       "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 5,  "pass_accuracy": 80,  "dribbles": 4,  "dribble_success_rate": 100, "tackles": 0, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0,  "possession_lost": 1, "minutes_played": 21, "distance_covered": 3.1,  "distance_sprinted": 1.8},
    {"player_id": 24, "match_rating": 5.7, "performance_type": "Outfield", "positions_played": ["CM"],       "goals": 0, "assists": 0, "shots": 2, "shot_accuracy": 50, "passes": 18, "pass_accuracy": 83,  "dribbles": 20, "dribble_success_rate": 95,  "tackles": 9, "tackle_success_rate": 11,  "offsides": 0, "fouls_committed": 1, "possession_won": 1,  "possession_lost": 4, "minutes_played": 71, "distance_covered": 10.1, "distance_sprinted": 4.6},
    {"player_id": 63, "match_rating": 5.7, "performance_type": "Outfield", "positions_played": ["CDM"],      "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 22, "pass_accuracy": 86,  "dribbles": 19, "dribble_success_rate": 89,  "tackles": 7, "tackle_success_rate": 43,  "offsides": 0, "fouls_committed": 1, "possession_won": 4,  "possession_lost": 2, "minutes_played": 92, "distance_covered": 11.7, "distance_sprinted": 4.1},
    {"player_id": 4,  "match_rating": 5.9, "performance_type": "Outfield", "positions_played": ["LB"],       "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 8,  "pass_accuracy": 63,  "dribbles": 5,  "dribble_success_rate": 100, "tackles": 7, "tackle_success_rate": 43,  "offsides": 0, "fouls_committed": 0, "possession_won": 4,  "possession_lost": 2, "minutes_played": 47, "distance_covered": 5.4,  "distance_sprinted": 2.0},
    {"player_id": 64, "match_rating": 7.1, "performance_type": "Outfield", "positions_played": ["LB"],       "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 16, "pass_accuracy": 94,  "dribbles": 15, "dribble_success_rate": 93,  "tackles": 8, "tackle_success_rate": 25,  "offsides": 0, "fouls_committed": 1, "possession_won": 4,  "possession_lost": 2, "minutes_played": 45, "distance_covered": 5.4,  "distance_sprinted": 1.8},
    {"player_id": 11, "match_rating": 6.9, "performance_type": "Outfield", "positions_played": ["CB"],       "goals": 0, "assists": 0, "shots": 1, "shot_accuracy": 0,  "passes": 21, "pass_accuracy": 100, "dribbles": 19, "dribble_success_rate": 95,  "tackles": 9, "tackle_success_rate": 56,  "offsides": 0, "fouls_committed": 1, "possession_won": 11, "possession_lost": 2, "minutes_played": 92, "distance_covered": 10.3, "distance_sprinted": 3.0},
    {"player_id": 53, "match_rating": 6.1, "performance_type": "Outfield", "positions_played": ["CB"],       "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 12, "pass_accuracy": 83,  "dribbles": 14, "dribble_success_rate": 71,  "tackles": 9, "tackle_success_rate": 78,  "offsides": 0, "fouls_committed": 0, "possession_won": 10, "possession_lost": 6, "minutes_played": 92, "distance_covered": 9.9,  "distance_sprinted": 3.2},
    {"player_id": 52, "match_rating": 6.1, "performance_type": "Outfield", "positions_played": ["RB"],       "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 16, "pass_accuracy": 81,  "dribbles": 17, "dribble_success_rate": 88,  "tackles": 8, "tackle_success_rate": 50,  "offsides": 0, "fouls_committed": 1, "possession_won": 4,  "possession_lost": 2, "minutes_played": 92, "distance_covered": 13.3, "distance_sprinted": 7.4},
]

print("--- REAL MATCH: FC Barcelona 1-0 Valencia CF (Supercopa De España, 2031-01-12) ---")
for p in match_87_outfield:
    pos = "/".join(p["positions_played"])
    label = f"P{p['player_id']} {pos} {p['minutes_played']}m ({p['goals']}G {p['assists']}A)"
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    rating = service.calculate_outfield_rating(p, match_87_overview, half_length=10, team_name=team_name)
    print(f"{label.ljust(38)} => Rating: {rating}  [Prev. algo: {p['match_rating']}]")
# Out:
# --- REAL MATCH: FC Barcelona 1-0 Valencia CF (Supercopa De España, 2031-01-12) ---
# P40 LW 47m (0G 0A)                     => Rating: 6.4  [Prev. algo: 6.8]
# P70 LW 45m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.3]
# P48 ST 21m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.5]
# P65 ST 63m (0G 0A)                     => Rating: 5.4  [Prev. algo: 4.6]
# P32 CM/ST 71m (0G 0A)                  => Rating: 6.8  [Prev. algo: 7.0]
# P45 RW 92m (0G 0A)                     => Rating: 5.5  [Prev. algo: 5.0]
# P31 CM 29m (0G 0A)                     => Rating: 5.8  [Prev. algo: 5.9]
# P41 CM 21m (0G 0A)                     => Rating: 5.8  [Prev. algo: 5.9]
# P24 CM 71m (0G 0A)                     => Rating: 5.8  [Prev. algo: 5.7]
# P63 CDM 92m (0G 0A)                    => Rating: 5.8  [Prev. algo: 5.7]
# P4 LB 47m (0G 0A)                      => Rating: 5.8  [Prev. algo: 5.9]
# P64 LB 45m (0G 0A)                     => Rating: 6.7  [Prev. algo: 7.1]
# ...

# %%
# Match 97: RC Celta 0-1 Valencia CF (La Liga, 2031-02-21)
# Disciplined away win — dominant possession (61%), tight defensive structure, rating spread 4.6 - 8.1
match_97_overview = {
    "in_game_date": "2031-02-21T00:00:00",
    "half_length": 10,
    "competition": "La Liga",
    "home_team_name": "RC Celta",
    "away_team_name": "Valencia CF",
    "home_score": 0,
    "away_score": 1,
    "home_stats": {"possession": 39, "xg": 1.5},
    "away_stats": {"possession": 61, "xg": 2.7},
}
team_name = "Valencia CF"

match_97_outfield = [
    {"player_id": 33, "match_rating": 5.5, "performance_type": "Outfield", "positions_played": ["LW"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 2,  "pass_accuracy": 50,  "dribbles": 1,  "dribble_success_rate": 100, "tackles": 1, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 0, "minutes_played": 13, "distance_covered": 1.7,  "distance_sprinted": 0.6},
    {"player_id": 40, "match_rating": 5.9, "performance_type": "Outfield", "positions_played": ["LW"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 8,  "pass_accuracy": 75,  "dribbles": 5,  "dribble_success_rate": 100, "tackles": 1, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 1, "minutes_played": 78, "distance_covered": 10.9, "distance_sprinted": 5.0},
    {"player_id": 65, "match_rating": 4.6, "performance_type": "Outfield", "positions_played": ["ST"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 0,  "pass_accuracy": 0,   "dribbles": 1,  "dribble_success_rate": 0,   "tackles": 1, "tackle_success_rate": 100, "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 1, "minutes_played": 14, "distance_covered": 1.7,  "distance_sprinted": 0.4},
    {"player_id": 48, "match_rating": 5.6, "performance_type": "Outfield", "positions_played": ["ST"],  "goals": 0, "assists": 0, "shots": 2, "shot_accuracy": 100,  "passes": 7,  "pass_accuracy": 86,  "dribbles": 6,  "dribble_success_rate": 67,  "tackles": 3, "tackle_success_rate": 33,  "offsides": 0, "fouls_committed": 0, "possession_won": 2, "possession_lost": 5, "minutes_played": 77, "distance_covered": 9.1,  "distance_sprinted": 1.8},
    {"player_id": 66, "match_rating": 7.6, "performance_type": "Outfield", "positions_played": ["RW"],  "goals": 1, "assists": 0, "shots": 2, "shot_accuracy": 100,  "passes": 21, "pass_accuracy": 90,  "dribbles": 22, "dribble_success_rate": 86,  "tackles": 1, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 6, "minutes_played": 91, "distance_covered": 10.6, "distance_sprinted": 2.2},
    {"player_id": 31, "match_rating": 6.9, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 1, "shots": 1, "shot_accuracy": 100,  "passes": 36, "pass_accuracy": 89,  "dribbles": 32, "dribble_success_rate": 91,  "tackles": 4, "tackle_success_rate": 25,  "offsides": 0, "fouls_committed": 0, "possession_won": 2, "possession_lost": 7, "minutes_played": 91, "distance_covered": 11.6, "distance_sprinted": 2.4},
    {"player_id": 32, "match_rating": 5.5, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 0, "shots": 1, "shot_accuracy": 0,   "passes": 1,  "pass_accuracy": 100, "dribbles": 1,  "dribble_success_rate": 100, "tackles": 0, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 0, "minutes_played": 14, "distance_covered": 1.8,  "distance_sprinted": 0.6},
    {"player_id": 24, "match_rating": 7.1, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 0, "shots": 1, "shot_accuracy": 0,   "passes": 43, "pass_accuracy": 88,  "dribbles": 35, "dribble_success_rate": 91,  "tackles": 6, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 3, "possession_lost": 8, "minutes_played": 77, "distance_covered": 11.4, "distance_sprinted": 5.5},
    {"player_id": 63, "match_rating": 8.1, "performance_type": "Outfield", "positions_played": ["CDM"], "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 55, "pass_accuracy": 91,  "dribbles": 47, "dribble_success_rate": 100, "tackles": 5, "tackle_success_rate": 40,  "offsides": 0, "fouls_committed": 0, "possession_won": 5, "possession_lost": 3, "minutes_played": 91, "distance_covered": 11.5, "distance_sprinted": 3.4},
    {"player_id": 64, "match_rating": 6.3, "performance_type": "Outfield", "positions_played": ["LB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 20, "pass_accuracy": 90,  "dribbles": 15, "dribble_success_rate": 100, "tackles": 3, "tackle_success_rate": 33,  "offsides": 0, "fouls_committed": 0, "possession_won": 5, "possession_lost": 1, "minutes_played": 91, "distance_covered": 10.2, "distance_sprinted": 2.9},
    {"player_id": 11, "match_rating": 6.8, "performance_type": "Outfield", "positions_played": ["CB"],  "goals": 0, "assists": 0, "shots": 1, "shot_accuracy": 0,   "passes": 28, "pass_accuracy": 96,  "dribbles": 25, "dribble_success_rate": 96,  "tackles": 7, "tackle_success_rate": 0,   "offsides": 0, "fouls_committed": 0, "possession_won": 4, "possession_lost": 2, "minutes_played": 91, "distance_covered": 10.6, "distance_sprinted": 3.0},
    {"player_id": 14, "match_rating": 6.9, "performance_type": "Outfield", "positions_played": ["CB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 31, "pass_accuracy": 87,  "dribbles": 19, "dribble_success_rate": 100, "tackles": 9, "tackle_success_rate": 56,  "offsides": 0, "fouls_committed": 0, "possession_won": 7, "possession_lost": 3, "minutes_played": 91, "distance_covered": 9.8,  "distance_sprinted": 2.6},
    {"player_id": 20, "match_rating": 6.8, "performance_type": "Outfield", "positions_played": ["RB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 2,  "pass_accuracy": 100, "dribbles": 2,  "dribble_success_rate": 100, "tackles": 2, "tackle_success_rate": 50,  "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 0, "minutes_played": 14, "distance_covered": 1.8,  "distance_sprinted": 0.7},
    {"player_id": 52, "match_rating": 7.4, "performance_type": "Outfield", "positions_played": ["RB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,   "passes": 24, "pass_accuracy": 75,  "dribbles": 18, "dribble_success_rate": 94,  "tackles": 11, "tackle_success_rate": 45, "offsides": 0, "fouls_committed": 0, "possession_won": 4, "possession_lost": 6, "minutes_played": 77, "distance_covered": 11.9, "distance_sprinted": 6.6},
]

print("--- REAL MATCH: RC Celta 0-1 Valencia CF (La Liga, 2031-02-21) ---")
for p in match_97_outfield:
    pos = "/".join(p["positions_played"])
    label = f"P{p['player_id']} {pos} {p['minutes_played']}m ({p['goals']}G {p['assists']}A)"
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    rating = service.calculate_outfield_rating(p, match_97_overview, half_length=10, team_name=team_name)
    print(f"{label.ljust(38)} => Rating: {rating}  [Prev. algo: {p['match_rating']}]")
# Out:
# --- REAL MATCH: RC Celta 0-1 Valencia CF (La Liga, 2031-02-21) ---
# P33 LW 13m (0G 0A)                     => Rating: 5.8  [Prev. algo: 5.5]
# P40 LW 78m (0G 0A)                     => Rating: 5.8  [Prev. algo: 5.9]
# P65 ST 14m (0G 0A)                     => Rating: 5.7  [Prev. algo: 4.6]
# P48 ST 77m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.6]
# P66 RW 91m (1G 0A)                     => Rating: 7.4  [Prev. algo: 7.6]
# P31 CM 91m (0G 1A)                     => Rating: 7.3  [Prev. algo: 6.9]
# P32 CM 14m (0G 0A)                     => Rating: 5.8  [Prev. algo: 5.5]
# P24 CM 77m (0G 0A)                     => Rating: 6.6  [Prev. algo: 7.1]
# P63 CDM 91m (0G 0A)                    => Rating: 7.9  [Prev. algo: 8.1]
# P64 LB 91m (0G 0A)                     => Rating: 6.2  [Prev. algo: 6.3]
# P11 CB 91m (0G 0A)                     => Rating: 6.4  [Prev. algo: 6.8]
# P14 CB 91m (0G 0A)                     => Rating: 6.9  [Prev. algo: 6.9]
# ...

# %%
# Match 103: Valencia CF 5-0 CD Leganes (La Liga, 2031-03-15)
# Total demolition at home — dominant possession (67%), high xG (6.0), rating spread 5.7 - 9.0
match_103_overview = {
    "in_game_date": "2031-03-15T00:00:00",
    "half_length": 10,
    "competition": "La Liga",
    "home_team_name": "Valencia CF",
    "away_team_name": "CD Leganes",
    "home_score": 5,
    "away_score": 0,
    "home_stats": {"possession": 67, "xg": 6.0},
    "away_stats": {"possession": 33, "xg": 0.6},
}
team_name = "Valencia CF"

match_103_outfield = [
    {"player_id": 40, "match_rating": 8.1, "performance_type": "Outfield", "positions_played": ["LW"],        "goals": 0, "assists": 1, "shots": 1, "shot_accuracy": 0,  "passes": 32, "pass_accuracy": 81,  "dribbles": 29, "dribble_success_rate": 90,  "tackles": 0, "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 9, "minutes_played": 91, "distance_covered": 13.3, "distance_sprinted": 6.3},
    {"player_id": 32, "match_rating": 5.7, "performance_type": "Outfield", "positions_played": ["ST"],        "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 3,  "pass_accuracy": 67,  "dribbles": 3,  "dribble_success_rate": 100, "tackles": 1, "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 1, "minutes_played": 11, "distance_covered": 1.2,  "distance_sprinted": 0.3},
    {"player_id": 48, "match_rating": 8.6, "performance_type": "Outfield", "positions_played": ["ST"],        "goals": 1, "assists": 0, "shots": 7, "shot_accuracy": 29, "passes": 15, "pass_accuracy": 87,  "dribbles": 18, "dribble_success_rate": 83,  "tackles": 4, "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 8, "minutes_played": 80, "distance_covered": 9.6,  "distance_sprinted": 2.0},
    {"player_id": 66, "match_rating": 9.0, "performance_type": "Outfield", "positions_played": ["RW"],        "goals": 2, "assists": 1, "shots": 5, "shot_accuracy": 40, "passes": 20, "pass_accuracy": 95,  "dribbles": 27, "dribble_success_rate": 78,  "tackles": 1, "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 9, "minutes_played": 91, "distance_covered": 11.2, "distance_sprinted": 2.9},
    {"player_id": 31, "match_rating": 5.7, "performance_type": "Outfield", "positions_played": ["CM"],        "goals": 0, "assists": 0, "shots": 1, "shot_accuracy": 0,  "passes": 43, "pass_accuracy": 88,  "dribbles": 37, "dribble_success_rate": 86,  "tackles": 5, "tackle_success_rate": 20, "offsides": 0, "fouls_committed": 1, "possession_won": 4, "possession_lost": 6, "minutes_played": 91, "distance_covered": 11.7, "distance_sprinted": 3.0},
    {"player_id": 56, "match_rating": 7.8, "performance_type": "Outfield", "positions_played": ["CM"],        "goals": 1, "assists": 0, "shots": 2, "shot_accuracy": 50, "passes": 2,  "pass_accuracy": 100, "dribbles": 3,  "dribble_success_rate": 100, "tackles": 1, "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 0, "minutes_played": 11, "distance_covered": 1.5,  "distance_sprinted": 0.8},
    {"player_id": 24, "match_rating": 8.8, "performance_type": "Outfield", "positions_played": ["CM"],        "goals": 1, "assists": 1, "shots": 3, "shot_accuracy": 33, "passes": 43, "pass_accuracy": 91,  "dribbles": 40, "dribble_success_rate": 93,  "tackles": 1, "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 3, "possession_lost": 5, "minutes_played": 80, "distance_covered": 12.1, "distance_sprinted": 6.0},
    {"player_id": 63, "match_rating": 7.8, "performance_type": "Outfield", "positions_played": ["CDM"],       "goals": 0, "assists": 1, "shots": 0, "shot_accuracy": 0,  "passes": 44, "pass_accuracy": 95,  "dribbles": 30, "dribble_success_rate": 97,  "tackles": 2, "tackle_success_rate": 50, "offsides": 0, "fouls_committed": 0, "possession_won": 6, "possession_lost": 2, "minutes_played": 91, "distance_covered": 11.7, "distance_sprinted": 4.1},
    {"player_id": 4,  "match_rating": 6.1, "performance_type": "Outfield", "positions_played": ["LB"],        "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 2,  "pass_accuracy": 100, "dribbles": 3,  "dribble_success_rate": 67,  "tackles": 0, "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 1, "minutes_played": 11, "distance_covered": 1.2,  "distance_sprinted": 0.4},
    {"player_id": 11, "match_rating": 7.4, "performance_type": "Outfield", "positions_played": ["CB"],        "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 14, "pass_accuracy": 93,  "dribbles": 8,  "dribble_success_rate": 88,  "tackles": 8, "tackle_success_rate": 63, "offsides": 0, "fouls_committed": 0, "possession_won": 8, "possession_lost": 0, "minutes_played": 91, "distance_covered": 10.5, "distance_sprinted": 3.4},
    {"player_id": 64, "match_rating": 6.2, "performance_type": "Outfield", "positions_played": ["LB", "CB"],  "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 13, "pass_accuracy": 92,  "dribbles": 9,  "dribble_success_rate": 100, "tackles": 8, "tackle_success_rate": 38, "offsides": 0, "fouls_committed": 1, "possession_won": 3, "possession_lost": 1, "minutes_played": 91, "distance_covered": 9.5,  "distance_sprinted": 2.4},
    {"player_id": 14, "match_rating": 7.3, "performance_type": "Outfield", "positions_played": ["CB"],        "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 6,  "pass_accuracy": 83,  "dribbles": 3,  "dribble_success_rate": 100, "tackles": 8, "tackle_success_rate": 88, "offsides": 0, "fouls_committed": 0, "possession_won": 9, "possession_lost": 0, "minutes_played": 80, "distance_covered": 8.1,  "distance_sprinted": 1.9},
    {"player_id": 52, "match_rating": 7.9, "performance_type": "Outfield", "positions_played": ["RB"],        "goals": 0, "assists": 0, "shots": 0, "shot_accuracy": 0,  "passes": 32, "pass_accuracy": 88,  "dribbles": 26, "dribble_success_rate": 100, "tackles": 6, "tackle_success_rate": 33, "offsides": 0, "fouls_committed": 1, "possession_won": 6, "possession_lost": 4, "minutes_played": 91, "distance_covered": 14.3, "distance_sprinted": 8.5},
]

print("--- REAL MATCH: Valencia CF 5-0 CD Leganes (La Liga, 2031-03-15) ---")
for p in match_103_outfield:
    pos = "/".join(p["positions_played"])
    label = f"P{p['player_id']} {pos} {p['minutes_played']}m ({p['goals']}G {p['assists']}A)"
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    rating = service.calculate_outfield_rating(p, match_103_overview, half_length=10, team_name=team_name)
    print(f"{label.ljust(38)} => Rating: {rating}  [Prev. algo: {p['match_rating']}]")
# Out:
# --- REAL MATCH: Valencia CF 5-0 CD Leganes (La Liga, 2031-03-15) ---
# P40 LW 91m (0G 1A)                     => Rating: 8.4  [Prev. algo: 8.1]
# P32 ST 11m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.7]
# P48 ST 80m (1G 0A)                     => Rating: 8.0  [Prev. algo: 8.6]
# P66 RW 91m (2G 1A)                     => Rating: 9.2  [Prev. algo: 9.0]
# P31 CM 91m (0G 0A)                     => Rating: 5.8  [Prev. algo: 5.7]
# P56 CM 11m (1G 0A)                     => Rating: 7.2  [Prev. algo: 7.8]
# P24 CM 80m (1G 1A)                     => Rating: 8.7  [Prev. algo: 8.8]
# P63 CDM 91m (0G 1A)                    => Rating: 7.9  [Prev. algo: 7.8]
# P4 LB 11m (0G 0A)                      => Rating: 5.8  [Prev. algo: 6.1]
# P11 CB 91m (0G 0A)                     => Rating: 7.5  [Prev. algo: 7.4]
# P64 LB/CB 91m (0G 0A)                  => Rating: 6.1  [Prev. algo: 6.2]
# P14 CB 80m (0G 0A)                     => Rating: 7.4  [Prev. algo: 7.3]
# ...

# %%
# Match 106: Valencia CF 4-0 UD Almeria (La Liga, 2031-04-05)
# Comfortable home win — notable for P32 (CM) scoring a hat-trick in 26 minutes (9.2 prev. algo)
match_106_overview = {
    "in_game_date": "2031-04-05T00:00:00",
    "half_length": 10,
    "competition": "La Liga",
    "home_team_name": "Valencia CF",
    "away_team_name": "UD Almeria",
    "home_score": 4,
    "away_score": 0,
    "home_stats": {"possession": 59, "xg": 6.4},
    "away_stats": {"possession": 41, "xg": 0.2},
}
team_name = "Valencia CF"

match_106_outfield = [
    {"player_id": 33, "match_rating": 8.7, "performance_type": "Outfield", "positions_played": ["LW"],  "goals": 0, "assists": 2, "shots": 0,  "shot_accuracy": 0,   "passes": 36, "pass_accuracy": 67,  "dribbles": 35, "dribble_success_rate": 91,  "tackles": 5,  "tackle_success_rate": 40, "offsides": 0, "fouls_committed": 0, "possession_won": 4, "possession_lost": 10, "minutes_played": 92, "distance_covered": 12.0, "distance_sprinted": 3.8},
    {"player_id": 48, "match_rating": 5.9, "performance_type": "Outfield", "positions_played": ["ST"],  "goals": 0, "assists": 0, "shots": 2,  "shot_accuracy": 50,  "passes": 2,  "pass_accuracy": 100, "dribbles": 4,  "dribble_success_rate": 100, "tackles": 0,  "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 1,  "minutes_played": 18, "distance_covered": 2.1,  "distance_sprinted": 0.4},
    {"player_id": 65, "match_rating": 8.2, "performance_type": "Outfield", "positions_played": ["ST"],  "goals": 1, "assists": 0, "shots": 4,  "shot_accuracy": 50,  "passes": 11, "pass_accuracy": 82,  "dribbles": 13, "dribble_success_rate": 92,  "tackles": 1,  "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 6,  "minutes_played": 74, "distance_covered": 8.7,  "distance_sprinted": 2.0},
    {"player_id": 45, "match_rating": 4.9, "performance_type": "Outfield", "positions_played": ["RW"],  "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,   "passes": 3,  "pass_accuracy": 33,  "dribbles": 2,  "dribble_success_rate": 100, "tackles": 0,  "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 2,  "minutes_played": 26, "distance_covered": 3.0,  "distance_sprinted": 1.1},
    {"player_id": 66, "match_rating": 5.4, "performance_type": "Outfield", "positions_played": ["RW"],  "goals": 0, "assists": 0, "shots": 4,  "shot_accuracy": 25,  "passes": 16, "pass_accuracy": 88,  "dribbles": 19, "dribble_success_rate": 84,  "tackles": 3,  "tackle_success_rate": 33, "offsides": 0, "fouls_committed": 1, "possession_won": 1, "possession_lost": 6,  "minutes_played": 66, "distance_covered": 8.2,  "distance_sprinted": 2.0},
    {"player_id": 40, "match_rating": 6.3, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,   "passes": 15, "pass_accuracy": 93,  "dribbles": 13, "dribble_success_rate": 100, "tackles": 0,  "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 0, "possession_lost": 0,  "minutes_played": 26, "distance_covered": 3.3,  "distance_sprinted": 0.9},
    {"player_id": 31, "match_rating": 5.7, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 0, "shots": 1,  "shot_accuracy": 100, "passes": 29, "pass_accuracy": 79,  "dribbles": 22, "dribble_success_rate": 91,  "tackles": 2,  "tackle_success_rate": 50, "offsides": 0, "fouls_committed": 0, "possession_won": 3, "possession_lost": 7,  "minutes_played": 66, "distance_covered": 8.5,  "distance_sprinted": 2.4},
    {"player_id": 32, "match_rating": 9.2, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 3, "assists": 0, "shots": 3,  "shot_accuracy": 100, "passes": 10, "pass_accuracy": 90,  "dribbles": 9,  "dribble_success_rate": 100, "tackles": 2,  "tackle_success_rate": 50, "offsides": 0, "fouls_committed": 0, "possession_won": 1, "possession_lost": 1,  "minutes_played": 26, "distance_covered": 3.3,  "distance_sprinted": 1.1},
    {"player_id": 24, "match_rating": 7.4, "performance_type": "Outfield", "positions_played": ["CM"],  "goals": 0, "assists": 0, "shots": 5,  "shot_accuracy": 60,  "passes": 26, "pass_accuracy": 88,  "dribbles": 29, "dribble_success_rate": 97,  "tackles": 8,  "tackle_success_rate": 63, "offsides": 0, "fouls_committed": 0, "possession_won": 5, "possession_lost": 7,  "minutes_played": 66, "distance_covered": 10.1, "distance_sprinted": 5.3},
    {"player_id": 63, "match_rating": 7.3, "performance_type": "Outfield", "positions_played": ["CDM"], "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,   "passes": 34, "pass_accuracy": 91,  "dribbles": 22, "dribble_success_rate": 95,  "tackles": 5,  "tackle_success_rate": 60, "offsides": 0, "fouls_committed": 0, "possession_won": 5, "possession_lost": 0,  "minutes_played": 92, "distance_covered": 11.1, "distance_sprinted": 3.4},
    {"player_id": 4,  "match_rating": 6.4, "performance_type": "Outfield", "positions_played": ["LB"],  "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,   "passes": 3,  "pass_accuracy": 100, "dribbles": 1,  "dribble_success_rate": 100, "tackles": 0,  "tackle_success_rate": 0,  "offsides": 0, "fouls_committed": 0, "possession_won": 2, "possession_lost": 0,  "minutes_played": 18, "distance_covered": 1.9,  "distance_sprinted": 0.5},
    {"player_id": 64, "match_rating": 6.4, "performance_type": "Outfield", "positions_played": ["LB"],  "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,   "passes": 8,  "pass_accuracy": 100, "dribbles": 4,  "dribble_success_rate": 100, "tackles": 4,  "tackle_success_rate": 50, "offsides": 0, "fouls_committed": 0, "possession_won": 3, "possession_lost": 0,  "minutes_played": 74, "distance_covered": 7.0,  "distance_sprinted": 1.5},
    {"player_id": 11, "match_rating": 6.4, "performance_type": "Outfield", "positions_played": ["CB"],  "goals": 0, "assists": 0, "shots": 1,  "shot_accuracy": 0,   "passes": 20, "pass_accuracy": 85,  "dribbles": 14, "dribble_success_rate": 100, "tackles": 4,  "tackle_success_rate": 50, "offsides": 0, "fouls_committed": 0, "possession_won": 6, "possession_lost": 2,  "minutes_played": 92, "distance_covered": 9.9,  "distance_sprinted": 2.6},
    {"player_id": 14, "match_rating": 6.2, "performance_type": "Outfield", "positions_played": ["CB"],  "goals": 0, "assists": 0, "shots": 0,  "shot_accuracy": 0,   "passes": 7,  "pass_accuracy": 100, "dribbles": 4,  "dribble_success_rate": 100, "tackles": 4,  "tackle_success_rate": 50, "offsides": 0, "fouls_committed": 0, "possession_won": 4, "possession_lost": 0,  "minutes_played": 92, "distance_covered": 8.9,  "distance_sprinted": 2.2},
    {"player_id": 52, "match_rating": 8.5, "performance_type": "Outfield", "positions_played": ["RB"],  "goals": 0, "assists": 1, "shots": 0,  "shot_accuracy": 0,   "passes": 21, "pass_accuracy": 95,  "dribbles": 18, "dribble_success_rate": 94,  "tackles": 10, "tackle_success_rate": 80, "offsides": 0, "fouls_committed": 1, "possession_won": 8, "possession_lost": 1,  "minutes_played": 92, "distance_covered": 13.3, "distance_sprinted": 7.1},
]

print("--- REAL MATCH: Valencia CF 4-0 UD Almeria (La Liga, 2031-04-05) ---")
for p in match_106_outfield:
    pos = "/".join(p["positions_played"])
    label = f"P{p['player_id']} {pos} {p['minutes_played']}m ({p['goals']}G {p['assists']}A)"
    service = MatchRatingsService(weights=weights, means_stds=means_stds)
    rating = service.calculate_outfield_rating(p, match_106_overview, half_length=10, team_name=team_name)
    print(f"{label.ljust(38)} => Rating: {rating}  [Prev. algo: {p['match_rating']}]")
# Out:
# --- REAL MATCH: Valencia CF 4-0 UD Almeria (La Liga, 2031-04-05) ---
# P33 LW 92m (0G 2A)                     => Rating: 9.2  [Prev. algo: 8.7]
# P48 ST 18m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.9]
# P65 ST 74m (1G 0A)                     => Rating: 7.5  [Prev. algo: 8.2]
# P45 RW 26m (0G 0A)                     => Rating: 5.5  [Prev. algo: 4.9]
# P66 RW 66m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.4]
# P40 CM 26m (0G 0A)                     => Rating: 5.9  [Prev. algo: 6.3]
# P31 CM 66m (0G 0A)                     => Rating: 5.7  [Prev. algo: 5.7]
# P32 CM 26m (3G 0A)                     => Rating: 9.1  [Prev. algo: 9.2]
# P24 CM 66m (0G 0A)                     => Rating: 7.0  [Prev. algo: 7.4]
# P63 CDM 92m (0G 0A)                    => Rating: 7.0  [Prev. algo: 7.3]
# P4 LB 18m (0G 0A)                      => Rating: 6.1  [Prev. algo: 6.4]
# P64 LB 74m (0G 0A)                     => Rating: 6.0  [Prev. algo: 6.4]
# ...
